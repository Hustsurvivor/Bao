# %%
# 分析bao的输出
import os 
import pandas as pd

def analyze_bao_output(file_path):
    with open(file_path)as f:
        lines = f.readlines()
    
    bao_hint = []
    bao_planning_time = []
    bao_exec_time = []
    qid = []
    for line in lines:
        items = line.split(',')
        if items[1].strip() != '2':
            continue
        bao_hint.append(items[0])
        bao_planning_time.append(items[-3])
        bao_exec_time.append(items[-2])
        qid.append(items[-4].split('/')[-1])

    data = {
        'qid': qid, 
        'bao_hint': bao_hint, 
        'bao_planning_time': bao_planning_time, 
        'bao_exec_time': bao_exec_time
    }
    df = pd.DataFrame(data)
    # 提取数字部分并转换为整数（假设格式为 "数字.sql"）
    df['qid_num'] = df['qid'].str.replace('.sql', '')
    
    # 按数字部分从小到大排序
    df = df.sort_values(by='qid_num', ascending=True)
    
    # 删除临时列（可选）
    df = df.drop(columns=['qid_num'])
    
    # df.to_csv('test_bao_tpch-2.csv', index=False)
    return df

# %%
df = analyze_bao_output('test__bao__stats-2.txt')

sum_bao_exec_time = sum(df['bao_exec_time'].astype(float))/1000.0
sum_bao_planning_time = sum(df['bao_planning_time'].astype(float))/1000.0

print(sum_bao_exec_time)
print(sum_bao_planning_time)
# Out:
# 3949.6305509999984
# 1086.6900509999996

# %%
df = analyze_bao_output('test__bao__stats.txt')

sum_bao_exec_time = sum(df['bao_exec_time'].astype(float))/1000.0
sum_bao_planning_time = sum(df['bao_planning_time'].astype(float))/1000.0

print(sum_bao_exec_time)
print(sum_bao_planning_time)
# Out:
# 8183.698072999998
# 2557.756690999999

# %%
df = analyze_bao_output('test__bao__tpch.txt')

sum_bao_exec_time = sum(df['bao_exec_time'].astype(float))/1000.0
sum_bao_planning_time = sum(df['bao_planning_time'].astype(float))/1000.0

print(sum_bao_exec_time)
print(sum_bao_planning_time)
# Out:
# 15517.335328999974
# 3291.739407000004

# %%
df = analyze_bao_output('test__bao__tpch-2.txt')

sum_bao_exec_time = sum(df['bao_exec_time'].astype(float))/1000.0
sum_bao_planning_time = sum(df['bao_planning_time'].astype(float))/1000.0

print(sum_bao_exec_time)
print(sum_bao_planning_time)
# Out:
# 4806.018895000002
# 14.862372000000008

# %%
# base_split_1
df = analyze_bao_output('test__bao__job_bs1.txt')
sum_bao_exec_time = sum(df['bao_exec_time'].astype(float))/1000.0
sum_bao_planning_time = sum(df['bao_planning_time'].astype(float))/1000.0

print(f'bao_planning: {sum_bao_planning_time}, bao_exec: {sum_bao_exec_time}')


pg_df = analyze_bao_output('test__bao__job_bs1_pg_test.txt')
sum_pg_exec_time = sum(pg_df['bao_exec_time'].astype(float))/1000.0
sum_pg_planning_time = sum(pg_df['bao_planning_time'].astype(float))/1000.0

print(f'pg_planning: {sum_pg_planning_time}, pg_exec: {sum_pg_exec_time}')

gmlr = 1.0
for bao_exec_time, pg_exec_time in zip(df['bao_exec_time'], pg_df['bao_exec_time']):
    gmlr *= (float(bao_exec_time) / float(pg_exec_time))

gmlr = gmlr ** (1.0/len(bao_exec_time))
print(f'gmlr: {gmlr}')

print(df)
# Out:
# bao_planning: 2.55091, bao_exec: 39.611633000000005
# pg_planning: 0.3809679999999999, pg_exec: 14.935356000000002
# gmlr: 4.724846801540376
#         qid                                           bao_hint  \
# 0   15a.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 1   15b.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 2   15c.sql                       SET enable_nestloop TO off;
# 3   15d.sql                       SET enable_nestloop TO off;
# 4   24a.sql                                          (no hint)
# 5   24b.sql                      SET enable_mergejoin TO off;
# 6   25a.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 7   25b.sql                                          (no hint)
# 8   25c.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 9    2a.sql                                          (no hint)
# 10   2b.sql                                          (no hint)
# 11   2c.sql                                          (no hint)
# 12   2d.sql                                          (no hint)
# 13  31a.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 14  31b.sql                       SET enable_nestloop TO off;
# 15  31c.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 16   7a.sql                       SET enable_nestloop TO off;
# 17   7b.sql                       SET enable_nestloop TO off;
# 18   7c.sql                       SET enable_nestloop TO off;
#
#    bao_planning_time bao_exec_time
# 0            117.393       342.283
# 1            101.706        30.401
# 2            118.609      1328.738
# 3            122.842       898.932
# 4             309.53       239.781
# 5            306.288        27.457
# 6             99.141      2710.034
# 7            120.327       178.006
# 8             94.047      7469.056
# 9             64.144       434.457
# 10            68.123       389.051
# 11            67.111       380.959
# 12            64.761       483.752
# 13           197.244      6119.766
# 14           215.761      1708.449
# 15           211.578      8863.111
# 16            91.582      2595.021
# 17            99.756      1915.468
# 18            80.967      3496.911

# %%
merged_df = pd.merge(df, pg_df, on='qid')
merged_df
# Out:
#         qid                                         bao_hint_x  \
# 0   15a.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 1   15b.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 2   15c.sql                       SET enable_nestloop TO off;
# 3   15d.sql                       SET enable_nestloop TO off;
# 4   24a.sql                                          (no hint)
# 5   24b.sql                      SET enable_mergejoin TO off;
# 6   25a.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 7   25b.sql                                          (no hint)
# 8   25c.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 9    2a.sql                                          (no hint)
# 10   2b.sql                                          (no hint)
# 11   2c.sql                                          (no hint)
# 12   2d.sql                                          (no hint)
# 13  31a.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 14  31b.sql                       SET enable_nestloop TO off;
# 15  31c.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 16   7a.sql                       SET enable_nestloop TO off;
# 17   7b.sql                       SET enable_nestloop TO off;
# 18   7c.sql                       SET enable_nestloop TO off;
#
#    bao_planning_time_x bao_exec_time_x bao_hint_y bao_planning_time_y  \
# 0              117.393         342.283          x              14.128
# 1              101.706          30.401          x               9.456
# 2              118.609        1328.738          x               9.611
# 3              122.842         898.932          x               9.322
# 4               309.53         239.781          x              58.765
# 5              306.288          27.457          x              58.401
# 6               99.141        2710.034          x               8.531
# 7              120.327         178.006          x              24.962
# 8               94.047        7469.056          x               7.945
# 9               64.144         434.457          x               0.859
# 10              68.123         389.051          x               1.133
# 11              67.111         380.959          x                0.87
# 12              64.761         483.752          x               1.057
# 13             197.244        6119.766          x              54.879
# 14             215.761        1708.449          x              54.979
# 15             211.578        8863.111          x              54.043
# 16              91.582        2595.021          x               3.782
# 17              99.756        1915.468          x               4.018
# 18              80.967        3496.911          x               4.227
#
#    bao_exec_time_y
# 0          209.969
# 1           23.047
# 2          441.919
# 3           619.48
# 4          241.827
# 5           23.994
# 6          1248.18
# 7          168.645
# 8         4684.917
# 9          385.257
# 10         422.144
# 11         363.055
# 12          543.05
# 13         912.369
# 14         219.562
# 15         924.214
# 16         662.489
# 17         157.557
# 18        2683.681

# %%
# leave_ont_out_split_1
df = analyze_bao_output('test__bao__job_l1out1.txt')
sum_bao_exec_time = sum(df['bao_exec_time'].astype(float))/1000.0
sum_bao_planning_time = sum(df['bao_planning_time'].astype(float))/1000.0

print(f'bao_planning: {sum_bao_planning_time}, bao_exec: {sum_bao_exec_time}')


pg_df = analyze_bao_output('test__bao__job_l1out1_pg.txt')
sum_pg_exec_time = sum(pg_df['bao_exec_time'].astype(float))/1000.0
sum_pg_planning_time = sum(pg_df['bao_planning_time'].astype(float))/1000.0

print(f'pg_planning: {sum_pg_planning_time}, pg_exec: {sum_pg_exec_time}')

gmlr = 1.0
for bao_exec_time, pg_exec_time in zip(df['bao_exec_time'], pg_df['bao_exec_time']):
    gmlr *= (float(bao_exec_time) / float(pg_exec_time))

gmlr = gmlr ** (1.0/len(bao_exec_time))
print(f'gmlr: {gmlr}')

merged_df = pd.merge(df, pg_df, on='qid')
merged_df
# Out:
# bao_planning: 4.7885159999999996, bao_exec: 29.227964
# pg_planning: 0.6472490000000001, pg_exec: 38.253988
# gmlr: 2.822773360690968
#         qid                                         bao_hint_x  \
# 0   10b.sql                       SET enable_nestloop TO off;
# 1   11b.sql                                          (no hint)
# 2   12c.sql                      SET enable_mergejoin TO off;
# 3   13b.sql                                          (no hint)
# 4   14a.sql                                          (no hint)
# 5   15b.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 6   16c.sql                       SET enable_nestloop TO off;
# 7   17c.sql                       SET enable_nestloop TO off;
# 8   18b.sql                                          (no hint)
# 9   19a.sql                                          (no hint)
# 10   1c.sql                       SET enable_nestloop TO off;
# 11  20c.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 12  21c.sql                       SET enable_nestloop TO off;
# 13  22b.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 14  23b.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 15  24a.sql                                          (no hint)
# 16  25a.sql                                          (no hint)
# 17  26c.sql                      SET enable_mergejoin TO off;
# 18  27c.sql                      SET enable_mergejoin TO off;
# 19  28a.sql                                          (no hint)
# 20  29b.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 21   2a.sql                       SET enable_nestloop TO off;
# 22  30a.sql  SET enable_mergejoin TO off; SET enable_indexs...
# 23  31b.sql                                          (no hint)
# 24  32b.sql                                          (no hint)
# 25  33c.sql                                          (no hint)
# 26   3b.sql                                          (no hint)
# 27   4a.sql                                          (no hint)
# 28   5a.sql                      SET enable_mergejoin TO off;
# 29   6b.sql                      SET enable_mergejoin TO off;
# 30   7c.sql                       SET enable_nestloop TO off;
# 31   8c.sql                                          (no hint)
# 32   9c.sql                       SET enable_nestloop TO off;
#
#    bao_planning_time_x bao_exec_time_x bao_hint_y bao_planning_time_y  \
# 0                72.38        1014.855          x               3.208
# 1               80.065          30.047          x               3.625
# 2              104.635         562.803          x              13.741
# 3              109.303         552.968          x              12.488
# 4               80.229         229.497          x               3.453
# 5               102.11          32.085          x               9.099
# 6              104.331        2584.432          x               4.722
# 7               94.651         1685.92          x               2.734
# 8                83.69         160.047          x               3.981
# 9              135.059         176.813          x              22.147
# 10              72.853         227.939          x               1.195
# 11             103.027         1029.03          x               8.912
# 12             106.316         370.557          x               8.732
# 13             163.211         291.112          x              23.583
# 14             162.782           41.29          x              22.957
# 15              308.35         251.481          x              57.667
# 16              97.777        1244.873          x               8.184
# 17             261.568        4407.767          x              54.771
# 18              270.37         110.357          x              49.003
# 19             329.102         375.807          x              61.987
# 20             436.509          19.986          x              83.623
# 21              72.741         464.501          x               0.877
# 22             269.988        3950.851          x              52.111
# 23              220.81         259.126          x              53.988
# 24              66.893          90.219          x               1.067
# 25             329.197          52.325          x              61.161
# 26              65.014          72.795          x                0.64
# 27              65.062           76.95          x               0.871
# 28              67.604          98.538          x               0.899
# 29              69.811         224.618          x               0.881
# 30              90.737        3599.506          x               4.019
# 31               81.53        2755.038          x               2.875
# 32             110.811        2183.831          x               8.048
#
#    bao_exec_time_y
# 0          179.075
# 1           25.547
# 2          499.869
# 3          466.041
# 4          222.566
# 5           22.422
# 6         1440.117
# 7         5499.265
# 8          150.272
# 9           163.57
# 10          90.791
# 11         922.483
# 12          62.019
# 13         200.124
# 14          41.876
# 15         248.791
# 16        1279.535
# 17       19070.278
# 18          44.112
# 19         321.619
# 20            72.6
# 21         380.307
# 22         448.077
# 23         225.404
# 24          80.807
# 25          50.541
# 26          57.108
# 27          72.223
# 28          98.519
# 29           126.8
# 30        2623.472
# 31        2733.905
# 32         333.853

# %%
# RND_1
df = analyze_bao_output('test__bao__job_RND1.txt')
sum_bao_exec_time = sum(df['bao_exec_time'].astype(float))/1000.0
sum_bao_planning_time = sum(df['bao_planning_time'].astype(float))/1000.0

print(f'bao_planning: {sum_bao_planning_time}, bao_exec: {sum_bao_exec_time}')


pg_df = analyze_bao_output('test__bao__job_rnd1_pg.txt')
sum_pg_exec_time = sum(pg_df['bao_exec_time'].astype(float))/1000.0
sum_pg_planning_time = sum(pg_df['bao_planning_time'].astype(float))/1000.0

print(f'pg_planning: {sum_pg_planning_time}, pg_exec: {sum_pg_exec_time}')

gmlr = 1.0
for bao_exec_time, pg_exec_time in zip(df['bao_exec_time'], pg_df['bao_exec_time']):
    gmlr *= (float(bao_exec_time) / float(pg_exec_time))

gmlr = gmlr ** (1.0/len(bao_exec_time))
print(f'gmlr: {gmlr}')

merged_df = pd.merge(df, pg_df, on='qid')
merged_df
# Out:
# bao_planning: 2.378233, bao_exec: 18.39851
# pg_planning: 0.20451599999999998, pg_exec: 26.520885999999997
# gmlr: 1.3209219726477173
#         qid                     bao_hint_x bao_planning_time_x  \
# 0   11d.sql  SET enable_mergejoin TO off;               79.485
# 1   15a.sql                      (no hint)              109.24
# 2   17b.sql   SET enable_nestloop TO off;               98.701
# 3   17e.sql   SET enable_nestloop TO off;                89.07
# 4   18b.sql  SET enable_mergejoin TO off;               81.396
# 5    1c.sql   SET enable_nestloop TO off;               77.204
# 6   20a.sql   SET enable_nestloop TO off;              126.052
# 7   21a.sql                      (no hint)             101.044
# 8   25c.sql   SET enable_nestloop TO off;              117.001
# 9   28b.sql   SET enable_nestloop TO off;              346.571
# 10   2c.sql                      (no hint)              62.261
# 11  32b.sql                      (no hint)              67.431
# 12  33a.sql                      (no hint)             336.884
# 13   4b.sql                      (no hint)                68.0
# 14   4c.sql                      (no hint)               81.61
# 15   5c.sql                      (no hint)              75.438
# 16   6a.sql                      (no hint)              67.624
# 17   6c.sql                      (no hint)              69.147
# 18   6e.sql                      (no hint)              66.241
# 19   8b.sql                      (no hint)               85.77
# 20   8c.sql                      (no hint)              72.046
# 21   9c.sql   SET enable_nestloop TO off;              100.017
#
#    bao_exec_time_x bao_hint_y bao_planning_time_y bao_exec_time_y
# 0          134.102          x               3.658         124.695
# 1          229.211          x               14.39         194.735
# 2         4165.107          x                2.79        5257.165
# 3          2671.93          x               3.225        9193.088
# 4          158.931          x               3.967         137.046
# 5          246.739          x               0.852          78.106
# 6         1636.926          x               8.923        1909.342
# 7            72.83          x               8.281          65.224
# 8         2088.329          x               8.306        4239.058
# 9          983.864          x              60.833        1061.266
# 10         375.209          x               0.889         369.947
# 11          91.611          x               1.104          86.306
# 12          43.629          x              64.449          44.499
# 13          66.319          x               1.132          62.364
# 14          87.375          x               0.971          90.739
# 15          135.66          x               1.203          125.03
# 16          16.712          x                0.89          12.943
# 17          13.146          x               0.907           7.701
# 18          18.209          x               0.828          12.367
# 19         272.626          x               5.051           248.1
# 20        2705.256          x               2.594        2873.087
# 21        2184.789          x               9.273         328.078

# %%
with open('test__bao__job_imdb.txt')as f:
    lines = f.readlines()

exec_time = 0.0
for line in lines:
    time = line.split(',')[-2]
    exec_time += min(float(time), 5*60*1000)

print(exec_time)
print(exec_time / 1000.0 / 60 / 60)
# Out:
# 7029321.552999991
# 1.952589320277775

# %%
with open('test__bao__tpch.txt')as f:
    lines = f.readlines()

exec_time = 0.0
for line in lines:
    time = line.split(',')[-2]
    exec_time += min(float(time), 5*60*1000)

print(exec_time)
print(exec_time / 1000.0 / 60 / 60)
# Out:
# 10974440.298999995
# 3.0484556386111095

# %%
with open('test__bao__job_ext.txt')as f:
    lines = f.readlines()

exec_time = 0.0
for line in lines:
    time = line.split(',')[-2]
    exec_time += min(float(time), 5*60*1000)

print(exec_time)
print(exec_time / 1000.0 / 60 / 60)
# Out:
# 9866395.087999998
# 2.7406653022222214

# %%
with open('test__bao__imdb_sub.txt')as f:
    lines = f.readlines()

exec_time = 0.0
planning_time = 0.0
print(len(lines))
for line in lines:
    time = line.split(',')
    exec_time += min(float(time[-2]), 5*60*1000)
    planning_time += min(float(time[-3]), 5*60*1000)

print(exec_time)
print(exec_time / 1000.0 / 60 / 60)
print(planning_time / 1000.0 / 60 / 60)
# Out:
# 500
# 2161424.905000001
# 0.6003958069444447
# 0.011081436666666665

# %%
with open('test__bao__tpch.txt')as f:
    lines = f.readlines()

exec_time = 0.0
for line in lines:
    time = line.split(',')[-2]
    exec_time += min(float(time), 5*60*1000)

print(exec_time)
print(exec_time / 1000.0 / 60 / 60)
# Out:
# 6082453.92
# 1.6895705333333333

# %%
import re

with open('backup4join_order/imdb/test__bao__job_imdb.txt')as f:
    log_text = f.read()

lines = log_text.strip().split('\n')

results = []

for line in lines:
    parts = line.split(',')
    hint = parts[0].strip()
    path_match = re.search(r'/test/([^/]+)\.sql', line)

    if path_match:
        qname = path_match.group(1)
        if hint == '(no hint)' or hint == 'x':
            hint = 'PG'
        results.append(f"{qname}#####{hint}")
    else:
        assert 1

# 保存到文件（可选）
with open('imdb_bao_hint.txt', 'w') as f:
    for item in results:
        f.write(item + '\n')

# 打印结果
for item in results:
    print(item)
# Out:
# c1002#####SET enable_mergejoin TO off;
# c1012#####PG
# c1065#####SET enable_nestloop TO off;
# c107#####SET enable_nestloop TO off;
# c1075#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1089#####PG
# c1094#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1095#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1103#####SET enable_nestloop TO off;
# c1110#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1111#####PG
# c1117#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1135#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1146#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1168#####PG
# c1173#####SET enable_nestloop TO off;
# c12#####PG
# c123#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1232#####PG
# c1275#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1280#####SET enable_nestloop TO off;
# c1282#####SET enable_nestloop TO off;
# c1288#####PG
# c1298#####PG
# c1321#####PG
# c1330#####SET enable_mergejoin TO off;
# c1332#####PG
# c1337#####PG
# c1344#####SET enable_nestloop TO off;
# c1360#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1365#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1378#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c138#####PG
# c1381#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1383#####PG
# c1387#####PG
# c1399#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1402#####SET enable_mergejoin TO off;
# c1405#####SET enable_mergejoin TO off;
# c1419#####PG
# c1421#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1422#####SET enable_nestloop TO off;
# c1426#####PG
# c1444#####SET enable_nestloop TO off;
# c1451#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1454#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1473#####SET enable_nestloop TO off;
# c1481#####PG
# c1486#####PG
# c1493#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1509#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1523#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1528#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c154#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1542#####PG
# c155#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c158#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c160#####SET enable_nestloop TO off;
# c1605#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1606#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1609#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c1610#####SET enable_nestloop TO off;
# c1629#####PG
# c1638#####SET enable_nestloop TO off;
# c1640#####SET enable_mergejoin TO off;
# c191#####SET enable_nestloop TO off;
# c2007#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2008#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2026#####PG
# c2043#####PG
# c2044#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2075#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2095#####PG
# c2098#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2128#####PG
# c2137#####PG
# c2175#####PG
# c221#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2226#####PG
# c2254#####PG
# c2265#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2271#####PG
# c2302#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2310#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2311#####PG
# c2318#####PG
# c2327#####SET enable_nestloop TO off;
# c2338#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c234#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2342#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2371#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c238#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2383#####PG
# c2396#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c241#####SET enable_nestloop TO off;
# c2418#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c249#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2505#####SET enable_nestloop TO off;
# c2521#####PG
# c2534#####SET enable_mergejoin TO off;
# c2535#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2542#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2544#####SET enable_nestloop TO off;
# c2545#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2547#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2575#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2599#####SET enable_mergejoin TO off;
# c2601#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2619#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2623#####PG
# c2624#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2628#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2656#####SET enable_nestloop TO off;
# c2685#####PG
# c2698#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2711#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2716#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2719#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c2734#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c274#####SET enable_nestloop TO off;
# c2740#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c28#####SET enable_nestloop TO off;
# c282#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c290#####SET enable_mergejoin TO off;
# c293#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3086#####SET enable_nestloop TO off;
# c3094#####SET enable_mergejoin TO off;
# c31#####PG
# c3107#####SET enable_mergejoin TO off;
# c3108#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3109#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3125#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3126#####SET enable_nestloop TO off;
# c3140#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3144#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3164#####SET enable_nestloop TO off;
# c3179#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3186#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c320#####PG
# c3203#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3233#####SET enable_mergejoin TO off;
# c324#####PG
# c3251#####PG
# c3263#####SET enable_nestloop TO off;
# c3264#####PG
# c3285#####PG
# c3289#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3298#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3302#####PG
# c3324#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3327#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c335#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3358#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3411#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3417#####PG
# c3419#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3420#####SET enable_mergejoin TO off;
# c3430#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c344#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3474#####PG
# c3477#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c348#####PG
# c3493#####SET enable_nestloop TO off;
# c3509#####SET enable_nestloop TO off;
# c3516#####PG
# c353#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c354#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3545#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3552#####SET enable_nestloop TO off;
# c3558#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3578#####SET enable_mergejoin TO off;
# c359#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c36#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c361#####SET enable_mergejoin TO off;
# c3654#####PG
# c3665#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3696#####SET enable_nestloop TO off;
# c3711#####PG
# c3715#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3717#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3722#####PG
# c3740#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3752#####PG
# c3756#####PG
# c3758#####PG
# c3771#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3794#####PG
# c3795#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3813#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3845#####PG
# c3863#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3876#####SET enable_mergejoin TO off;
# c3880#####PG
# c3894#####PG
# c3898#####PG
# c3909#####PG
# c3910#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3919#####PG
# c3926#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3932#####PG
# c3938#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3945#####PG
# c3958#####SET enable_mergejoin TO off;
# c3959#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3962#####SET enable_nestloop TO off;
# c3967#####SET enable_nestloop TO off;
# c3968#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3971#####PG
# c3975#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c3976#####PG
# c3984#####PG
# c428#####PG
# c432#####SET enable_mergejoin TO off;
# c465#####PG
# c470#####SET enable_mergejoin TO off;
# c490#####SET enable_nestloop TO off;
# c492#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c501#####SET enable_nestloop TO off;
# c506#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c51#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c517#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c521#####PG
# c524#####PG
# c547#####PG
# c550#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c571#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c585#####PG
# c599#####SET enable_mergejoin TO off;
# c607#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c621#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c657#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c658#####SET enable_mergejoin TO off;
# c674#####PG
# c676#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c683#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c702#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c716#####PG
# c767#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# c86#####SET enable_nestloop TO off;
# c90#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1007#####SET enable_nestloop TO off;
# q1011#####SET enable_nestloop TO off;
# q103#####SET enable_nestloop TO off;
# q1102#####SET enable_mergejoin TO off;
# q1107#####SET enable_nestloop TO off;
# q1113#####SET enable_nestloop TO off;
# q1127#####SET enable_nestloop TO off;
# q1131#####SET enable_nestloop TO off;
# q1137#####SET enable_nestloop TO off;
# q1169#####SET enable_nestloop TO off;
# q1180#####PG
# q1185#####PG
# q122#####SET enable_nestloop TO off;
# q1241#####SET enable_nestloop TO off;
# q1246#####SET enable_nestloop TO off;
# q1253#####SET enable_nestloop TO off;
# q1254#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1269#####PG
# q1289#####SET enable_nestloop TO off;
# q1333#####SET enable_nestloop TO off;
# q1366#####PG
# q1367#####SET enable_nestloop TO off;
# q138#####SET enable_nestloop TO off;
# q1410#####SET enable_nestloop TO off;
# q1436#####PG
# q1449#####SET enable_mergejoin TO off;
# q1477#####SET enable_nestloop TO off;
# q151#####SET enable_nestloop TO off;
# q1513#####SET enable_nestloop TO off;
# q1520#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1529#####SET enable_mergejoin TO off;
# q153#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1535#####SET enable_nestloop TO off;
# q1536#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1544#####PG
# q1572#####SET enable_nestloop TO off;
# q1599#####PG
# q16#####PG
# q1601#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1611#####SET enable_nestloop TO off;
# q1626#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1629#####SET enable_nestloop TO off;
# q165#####SET enable_nestloop TO off;
# q1669#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1672#####SET enable_mergejoin TO off;
# q1676#####PG
# q1677#####SET enable_nestloop TO off;
# q1683#####SET enable_nestloop TO off;
# q1686#####SET enable_nestloop TO off;
# q1689#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1691#####SET enable_nestloop TO off;
# q1700#####SET enable_nestloop TO off;
# q1702#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1705#####SET enable_nestloop TO off;
# q1707#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1720#####SET enable_nestloop TO off;
# q173#####SET enable_nestloop TO off;
# q1738#####SET enable_nestloop TO off;
# q1740#####PG
# q1764#####SET enable_nestloop TO off;
# q177#####SET enable_nestloop TO off;
# q1778#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1804#####PG
# q1814#####SET enable_nestloop TO off;
# q1820#####SET enable_nestloop TO off;
# q1834#####PG
# q1835#####PG
# q1836#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1844#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1852#####PG
# q1873#####SET enable_nestloop TO off;
# q1876#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1886#####SET enable_nestloop TO off;
# q1896#####SET enable_nestloop TO off;
# q1931#####SET enable_nestloop TO off;
# q1940#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1942#####SET enable_nestloop TO off;
# q1946#####SET enable_nestloop TO off;
# q1964#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q1968#####SET enable_nestloop TO off;
# q1973#####PG
# q1976#####PG
# q2054#####SET enable_nestloop TO off;
# q2101#####SET enable_nestloop TO off;
# q2103#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2107#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2108#####SET enable_nestloop TO off;
# q2111#####PG
# q2134#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2135#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2165#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2180#####SET enable_nestloop TO off;
# q2230#####SET enable_mergejoin TO off;
# q2232#####PG
# q2233#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2247#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2252#####PG
# q2269#####SET enable_nestloop TO off;
# q2273#####PG
# q2276#####SET enable_nestloop TO off;
# q2289#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2300#####SET enable_nestloop TO off;
# q2325#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2330#####PG
# q2336#####PG
# q235#####SET enable_nestloop TO off;
# q2357#####SET enable_nestloop TO off;
# q236#####SET enable_nestloop TO off;
# q2397#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2421#####SET enable_nestloop TO off;
# q2427#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2439#####PG
# q2450#####SET enable_nestloop TO off;
# q2454#####SET enable_nestloop TO off;
# q2458#####PG
# q2460#####PG
# q2474#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2476#####PG
# q2495#####PG
# q2577#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2615#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2629#####SET enable_nestloop TO off;
# q2631#####PG
# q2663#####SET enable_nestloop TO off;
# q2665#####SET enable_nestloop TO off;
# q2691#####SET enable_nestloop TO off;
# q27#####SET enable_nestloop TO off;
# q2704#####SET enable_nestloop TO off;
# q2738#####PG
# q2754#####PG
# q2765#####PG
# q2777#####SET enable_mergejoin TO off;
# q2804#####SET enable_nestloop TO off;
# q2815#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2838#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2846#####SET enable_nestloop TO off;
# q2851#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2853#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q2872#####SET enable_nestloop TO off;
# q2876#####PG
# q2896#####SET enable_mergejoin TO off;
# q2952#####SET enable_nestloop TO off;
# q296#####PG
# q2963#####PG
# q2967#####PG
# q3011#####SET enable_nestloop TO off;
# q3034#####PG
# q3043#####PG
# q3050#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3062#####SET enable_nestloop TO off;
# q3075#####PG
# q3083#####PG
# q311#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3118#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q312#####PG
# q3137#####SET enable_nestloop TO off;
# q316#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3160#####SET enable_nestloop TO off;
# q3211#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q323#####PG
# q3232#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3246#####SET enable_nestloop TO off;
# q3251#####SET enable_nestloop TO off;
# q3299#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3310#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3316#####SET enable_nestloop TO off;
# q336#####PG
# q3365#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3368#####SET enable_nestloop TO off;
# q337#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3374#####SET enable_mergejoin TO off;
# q3389#####PG
# q3416#####PG
# q3424#####SET enable_nestloop TO off;
# q3425#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3435#####SET enable_nestloop TO off;
# q344#####PG
# q345#####SET enable_nestloop TO off;
# q3462#####SET enable_nestloop TO off;
# q3469#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3485#####SET enable_nestloop TO off;
# q3487#####PG
# q3504#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3521#####PG
# q3525#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3530#####SET enable_nestloop TO off;
# q3556#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3562#####PG
# q3565#####PG
# q3581#####PG
# q360#####SET enable_nestloop TO off;
# q3614#####PG
# q3620#####SET enable_nestloop TO off;
# q3623#####PG
# q3634#####SET enable_nestloop TO off;
# q3650#####SET enable_nestloop TO off;
# q3677#####SET enable_nestloop TO off;
# q3709#####SET enable_nestloop TO off;
# q372#####PG
# q3724#####SET enable_nestloop TO off;
# q3727#####PG
# q3741#####PG
# q3743#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q375#####SET enable_nestloop TO off;
# q3810#####SET enable_nestloop TO off;
# q3834#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3836#####SET enable_nestloop TO off;
# q3840#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3864#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3865#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3866#####SET enable_nestloop TO off;
# q3878#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q3892#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q391#####SET enable_nestloop TO off;
# q3929#####PG
# q3954#####SET enable_nestloop TO off;
# q3957#####SET enable_nestloop TO off;
# q3973#####SET enable_nestloop TO off;
# q399#####SET enable_nestloop TO off;
# q3990#####SET enable_nestloop TO off;
# q428#####SET enable_mergejoin TO off;
# q434#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q450#####SET enable_nestloop TO off;
# q47#####PG
# q477#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q51#####PG
# q533#####SET enable_nestloop TO off;
# q558#####PG
# q569#####SET enable_nestloop TO off;
# q596#####SET enable_nestloop TO off;
# q603#####PG
# q610#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q614#####SET enable_nestloop TO off;
# q638#####SET enable_nestloop TO off;
# q648#####SET enable_nestloop TO off;
# q678#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q718#####PG
# q727#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q75#####SET enable_nestloop TO off;
# q782#####SET enable_nestloop TO off;
# q786#####PG
# q799#####PG
# q837#####PG
# q846#####PG
# q855#####PG
# q858#####SET enable_nestloop TO off;
# q87#####SET enable_nestloop TO off;
# q904#####PG
# q919#####SET enable_nestloop TO off;
# q949#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q966#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q99#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# q997#####SET enable_mergejoin TO off; SET enable_indexscan TO off;

# %%
import re

with open('backup4join_order/tpch/test__bao__tpch.txt')as f:
    log_text = f.read()

lines = log_text.strip().split('\n')

results = []

for line in lines:
    parts = line.split(',')
    hint = parts[0].strip()
    path_match = re.search(r'/test/([^/]+)\.sql', line)

    if path_match:
        qname = path_match.group(1)
        if hint == '(no hint)' or hint == 'x':
            hint = 'PG'
        results.append(f"{qname}#####{hint}")
    else:
        assert 1

# 保存到文件（可选）
with open('backup4join_order/tpch/tpch_bao_hint.txt', 'w') as f:
    for item in results:
        f.write(item + '\n')

# 打印结果
for item in results:
    print(item)
# Out:
# a1053#####PG
# a1063#####PG
# a1067#####PG
# a1073#####PG
# a1086#####PG
# a1089#####PG
# a1096#####PG
# a1111#####PG
# a1135#####PG
# a1148#####PG
# a1158#####PG
# a119#####PG
# a1221#####PG
# a1273#####PG
# a1291#####SET enable_nestloop TO off;
# a132#####PG
# a1343#####PG
# a1345#####PG
# a1346#####PG
# a1359#####PG
# a1367#####PG
# a1373#####PG
# a1400#####PG
# a1420#####PG
# a143#####PG
# a1488#####SET enable_nestloop TO off;
# a1510#####PG
# a1632#####PG
# a1644#####PG
# a165#####PG
# a1681#####SET enable_nestloop TO off;
# a1734#####PG
# a1765#####PG
# a1774#####SET enable_mergejoin TO off;
# a1817#####PG
# a1846#####PG
# a1857#####PG
# a1873#####PG
# a1907#####PG
# a1938#####PG
# a1942#####PG
# a1948#####PG
# a1952#####PG
# a1964#####PG
# a2015#####PG
# a2032#####SET enable_nestloop TO off;
# a2036#####PG
# a2137#####SET enable_mergejoin TO off;
# a2148#####PG
# a2174#####PG
# a219#####PG
# a2201#####PG
# a222#####PG
# a2267#####PG
# a2309#####PG
# a2315#####PG
# a2317#####PG
# a2335#####PG
# a2350#####PG
# a238#####PG
# a2463#####PG
# a2487#####PG
# a2502#####PG
# a2518#####SET enable_mergejoin TO off;
# a2609#####PG
# a2637#####PG
# a2643#####PG
# a2646#####PG
# a2684#####SET enable_nestloop TO off;
# a2719#####PG
# a2731#####PG
# a2751#####PG
# a2769#####PG
# a2808#####PG
# a286#####PG
# a2869#####PG
# a2923#####PG
# a2927#####PG
# a2946#####PG
# a2948#####PG
# a2987#####PG
# a3031#####PG
# a3038#####PG
# a3068#####PG
# a312#####PG
# a3144#####PG
# a3210#####PG
# a3211#####PG
# a323#####PG
# a3248#####PG
# a3264#####PG
# a3265#####PG
# a3272#####PG
# a3285#####PG
# a3289#####PG
# a3293#####PG
# a3314#####PG
# a3363#####PG
# a338#####PG
# a3403#####PG
# a3429#####SET enable_nestloop TO off;
# a3452#####PG
# a3456#####PG
# a3466#####PG
# a3473#####PG
# a3515#####PG
# a352#####PG
# a3529#####PG
# a3541#####PG
# a3582#####PG
# a3615#####PG
# a3646#####PG
# a3675#####PG
# a3698#####PG
# a3703#####PG
# a3726#####PG
# a3740#####SET enable_mergejoin TO off;
# a3757#####PG
# a3767#####PG
# a3769#####PG
# a3816#####PG
# a3825#####PG
# a3831#####PG
# a3844#####PG
# a3846#####PG
# a3864#####PG
# a3874#####PG
# a3893#####SET enable_mergejoin TO off;
# a3934#####PG
# a3936#####PG
# a3947#####PG
# a395#####PG
# a3968#####PG
# a3974#####PG
# a3976#####PG
# a398#####PG
# a3993#####PG
# a41#####PG
# a443#####PG
# a450#####PG
# a451#####PG
# a455#####PG
# a489#####PG
# a512#####PG
# a514#####PG
# a570#####PG
# a576#####PG
# a59#####PG
# a595#####PG
# a647#####SET enable_nestloop TO off;
# a710#####PG
# a713#####PG
# a726#####PG
# a776#####PG
# a791#####SET enable_mergejoin TO off;
# a794#####PG
# a804#####PG
# a819#####PG
# a824#####PG
# a863#####PG
# a964#####PG
# a983#####PG
# f1021#####PG
# f1024#####PG
# f1038#####PG
# f1050#####PG
# f1078#####PG
# f1080#####PG
# f1084#####PG
# f1103#####PG
# f1105#####PG
# f1113#####PG
# f1114#####SET enable_mergejoin TO off;
# f1129#####PG
# f114#####PG
# f1170#####PG
# f1182#####PG
# f1218#####PG
# f1222#####PG
# f1250#####PG
# f1259#####PG
# f1282#####PG
# f1291#####PG
# f1295#####PG
# f1322#####PG
# f1327#####PG
# f1334#####PG
# f134#####PG
# f1344#####PG
# f1365#####PG
# f1387#####PG
# f1397#####PG
# f1429#####PG
# f1433#####PG
# f1454#####PG
# f1459#####PG
# f146#####PG
# f1466#####PG
# f147#####PG
# f1474#####PG
# f1500#####PG
# f1503#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# f1524#####PG
# f1568#####PG
# f1583#####PG
# f1647#####PG
# f165#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# f1670#####PG
# f169#####PG
# f1698#####PG
# f1699#####PG
# f1714#####PG
# f1718#####PG
# f1729#####PG
# f1732#####PG
# f1736#####PG
# f1788#####PG
# f1790#####PG
# f1810#####PG
# f1813#####PG
# f1829#####PG
# f1872#####PG
# f1881#####PG
# f1887#####PG
# f1895#####PG
# f1905#####PG
# f1916#####PG
# f1921#####PG
# f1925#####PG
# f1926#####PG
# f1971#####PG
# f2002#####PG
# f2018#####PG
# f2063#####PG
# f2101#####PG
# f2110#####PG
# f2124#####PG
# f2148#####PG
# f2159#####PG
# f2167#####PG
# f2180#####PG
# f2184#####PG
# f2194#####PG
# f2222#####PG
# f2234#####PG
# f2249#####PG
# f2256#####PG
# f2262#####PG
# f2264#####PG
# f2268#####PG
# f227#####PG
# f2274#####PG
# f23#####PG
# f2306#####PG
# f2326#####PG
# f2338#####PG
# f2342#####PG
# f2354#####PG
# f236#####PG
# f2374#####PG
# f2382#####PG
# f2386#####PG
# f239#####PG
# f2392#####PG
# f2403#####PG
# f2405#####PG
# f2429#####PG
# f2431#####PG
# f2441#####PG
# f2466#####PG
# f2472#####PG
# f2483#####PG
# f2487#####PG
# f2489#####PG
# f2495#####PG
# f2507#####PG
# f2533#####PG
# f257#####PG
# f259#####PG
# f2607#####PG
# f2616#####PG
# f2647#####PG
# f2658#####PG
# f2667#####PG
# f2669#####PG
# f2680#####PG
# f2741#####PG
# f2762#####PG
# f2800#####PG
# f2804#####PG
# f2806#####PG
# f2810#####PG
# f2817#####PG
# f2823#####PG
# f2826#####PG
# f2846#####PG
# f2856#####PG
# f2881#####SET enable_mergejoin TO off;
# f2906#####PG
# f2916#####PG
# f2925#####PG
# f2933#####PG
# f294#####PG
# f2944#####PG
# f2950#####PG
# f2970#####PG
# f2978#####PG
# f3018#####PG
# f3019#####PG
# f3052#####PG
# f3084#####PG
# f3092#####PG
# f31#####PG
# f3121#####PG
# f3123#####PG
# f3131#####PG
# f3139#####PG
# f3207#####PG
# f324#####PG
# f3244#####PG
# f3258#####PG
# f3346#####PG
# f3362#####PG
# f3392#####PG
# f3414#####PG
# f3435#####PG
# f3438#####PG
# f3456#####PG
# f3471#####PG
# f3484#####PG
# f3505#####PG
# f3508#####PG
# f3514#####PG
# f352#####PG
# f353#####PG
# f3537#####PG
# f3541#####PG
# f3594#####PG
# f3613#####PG
# f3628#####PG
# f3657#####PG
# f3692#####PG
# f3695#####PG
# f3719#####PG
# f3730#####PG
# f3732#####PG
# f3740#####PG
# f3744#####PG
# f3746#####PG
# f3755#####PG
# f3770#####PG
# f3787#####PG
# f3793#####PG
# f3797#####PG
# f3808#####PG
# f3809#####PG
# f3810#####PG
# f3834#####PG
# f385#####PG
# f386#####PG
# f3882#####PG
# f3889#####PG
# f39#####PG
# f3915#####PG
# f3922#####PG
# f3949#####SET enable_nestloop TO off;
# f395#####PG
# f3987#####PG
# f402#####PG
# f408#####SET enable_mergejoin TO off;
# f409#####PG
# f410#####SET enable_nestloop TO off;
# f414#####PG
# f420#####PG
# f424#####PG
# f453#####PG
# f463#####PG
# f476#####PG
# f477#####PG
# f496#####PG
# f503#####PG
# f505#####PG
# f522#####PG
# f550#####PG
# f553#####PG
# f558#####PG
# f594#####PG
# f617#####PG
# f632#####PG
# f64#####PG
# f65#####PG
# f693#####PG
# f717#####PG
# f72#####PG
# f737#####PG
# f745#####PG
# f752#####PG
# f764#####PG
# f774#####PG
# f792#####PG
# f803#####PG
# f813#####PG
# f843#####PG
# f850#####PG
# f851#####PG
# f855#####PG
# f880#####PG
# f914#####PG
# f926#####PG
# f944#####PG
# f950#####PG
# f956#####PG

# %%
import re

with open('backup4join_order/job-ext/test__bao__job_ext.txt')as f:
    log_text = f.read()

lines = log_text.strip().split('\n')

results = []

for line in lines:
    parts = line.split(',')
    hint = parts[0].strip()
    path_match = re.search(r'/test/([^/]+)\.sql', line)

    if path_match:
        qname = path_match.group(1)
        if hint == '(no hint)' or hint == 'x':
            hint = 'PG'
        results.append(f"{qname}#####{hint}")
    else:
        assert 1

# 保存到文件（可选）
with open('backup4join_order/job-ext/bao_result.txt', 'w') as f:
    for item in results:
        f.write(item + '\n')

# 打印结果
for item in results:
    print(item)
# Out:
# a1006#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1015#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1033#####SET enable_nestloop TO off;
# a1052#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1069#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1083#####PG
# a1090#####SET enable_nestloop TO off;
# a1092#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a11#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1121#####PG
# a1128#####SET enable_nestloop TO off;
# a1143#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1157#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1176#####SET enable_nestloop TO off;
# a1180#####SET enable_mergejoin TO off;
# a1184#####SET enable_nestloop TO off;
# a1186#####SET enable_nestloop TO off;
# a1190#####PG
# a1223#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1232#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1245#####SET enable_nestloop TO off;
# a1251#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1253#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1266#####SET enable_nestloop TO off;
# a1272#####SET enable_nestloop TO off;
# a1281#####PG
# a1307#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1311#####PG
# a1324#####PG
# a1326#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1351#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a139#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1392#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1414#####SET enable_nestloop TO off;
# a1438#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1443#####SET enable_nestloop TO off;
# a1462#####SET enable_nestloop TO off;
# a1465#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a147#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1479#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a148#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1498#####PG
# a150#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1541#####SET enable_nestloop TO off;
# a1560#####SET enable_nestloop TO off;
# a1565#####SET enable_nestloop TO off;
# a1580#####SET enable_nestloop TO off;
# a1600#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1640#####SET enable_nestloop TO off;
# a1641#####SET enable_nestloop TO off;
# a1651#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1669#####SET enable_nestloop TO off;
# a1717#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1743#####SET enable_nestloop TO off;
# a1758#####SET enable_mergejoin TO off;
# a1773#####PG
# a1792#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1816#####PG
# a1821#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1838#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1844#####SET enable_nestloop TO off;
# a1869#####PG
# a187#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1883#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1892#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1900#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a192#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1920#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1926#####SET enable_nestloop TO off;
# a1946#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a1959#####SET enable_nestloop TO off;
# a1998#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2005#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2053#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2070#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2073#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2128#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a214#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2144#####SET enable_nestloop TO off;
# a215#####SET enable_nestloop TO off;
# a2163#####SET enable_nestloop TO off;
# a2189#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2196#####PG
# a2200#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2213#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2218#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2284#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2291#####SET enable_nestloop TO off;
# a2297#####SET enable_nestloop TO off;
# a2303#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2304#####PG
# a235#####PG
# a2362#####SET enable_nestloop TO off;
# a2397#####SET enable_nestloop TO off;
# a2411#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2425#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2426#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2436#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2458#####SET enable_nestloop TO off;
# a2469#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2478#####PG
# a2500#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2504#####PG
# a2509#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2534#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a254#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2546#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a255#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2551#####PG
# a2560#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2586#####SET enable_nestloop TO off;
# a2610#####SET enable_mergejoin TO off;
# a2613#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2621#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a264#####SET enable_nestloop TO off;
# a2642#####PG
# a2658#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2668#####SET enable_nestloop TO off;
# a2671#####SET enable_nestloop TO off;
# a2674#####SET enable_mergejoin TO off;
# a2680#####PG
# a2700#####SET enable_nestloop TO off;
# a2707#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2721#####SET enable_nestloop TO off;
# a2722#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2791#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2797#####SET enable_nestloop TO off;
# a2800#####SET enable_nestloop TO off;
# a2804#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2832#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2842#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2851#####SET enable_nestloop TO off;
# a2871#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2881#####SET enable_nestloop TO off;
# a2893#####SET enable_mergejoin TO off;
# a2900#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2909#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2920#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a2931#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a296#####SET enable_nestloop TO off;
# a297#####PG
# a2971#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3029#####PG
# a307#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3071#####SET enable_nestloop TO off;
# a3075#####SET enable_nestloop TO off;
# a3083#####SET enable_mergejoin TO off;
# a309#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3090#####PG
# a3092#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3119#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3128#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3134#####SET enable_nestloop TO off;
# a3157#####SET enable_nestloop TO off;
# a3160#####SET enable_nestloop TO off;
# a3161#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3207#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3209#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3226#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3230#####SET enable_nestloop TO off;
# a3232#####PG
# a3235#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3356#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3360#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3378#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3391#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3397#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3424#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3431#####SET enable_nestloop TO off;
# a3456#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3493#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3497#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3529#####PG
# a3563#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3575#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3601#####PG
# a3602#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3618#####SET enable_nestloop TO off;
# a3635#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3637#####SET enable_nestloop TO off;
# a3646#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3691#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3701#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a372#####SET enable_mergejoin TO off;
# a3738#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3741#####PG
# a3750#####SET enable_nestloop TO off;
# a378#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3781#####PG
# a3784#####SET enable_nestloop TO off;
# a38#####SET enable_nestloop TO off;
# a3856#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3864#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3879#####SET enable_nestloop TO off;
# a3883#####SET enable_nestloop TO off;
# a3884#####SET enable_nestloop TO off;
# a3920#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a3965#####SET enable_nestloop TO off;
# a3967#####PG
# a437#####SET enable_nestloop TO off;
# a441#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a449#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a477#####PG
# a5#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a502#####SET enable_nestloop TO off;
# a521#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a523#####PG
# a525#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a535#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a545#####SET enable_mergejoin TO off;
# a607#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a623#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a624#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a642#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a646#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a647#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a664#####SET enable_nestloop TO off;
# a683#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a685#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a715#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a718#####SET enable_nestloop TO off;
# a736#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a738#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a757#####PG
# a760#####PG
# a78#####SET enable_nestloop TO off;
# a782#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a797#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a803#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a817#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a821#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a826#####PG
# a845#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a854#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a86#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a878#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a889#####SET enable_nestloop TO off;
# a898#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a9#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a912#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a917#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# a933#####PG
# a934#####SET enable_nestloop TO off;
# a94#####SET enable_nestloop TO off;
# a95#####SET enable_nestloop TO off;
# a952#####SET enable_nestloop TO off;
# a968#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1002#####PG
# d1004#####PG
# d1008#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d102#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1026#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1048#####SET enable_mergejoin TO off;
# d1059#####PG
# d1062#####SET enable_nestloop TO off;
# d1071#####PG
# d1078#####SET enable_nestloop TO off;
# d1093#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1116#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d116#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1177#####SET enable_nestloop TO off;
# d1182#####PG
# d1192#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1230#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1236#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1259#####SET enable_mergejoin TO off;
# d1284#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1311#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1342#####PG
# d1344#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1348#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1424#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1433#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1444#####PG
# d147#####PG
# d1477#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d148#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1490#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1495#####PG
# d150#####SET enable_nestloop TO off;
# d1513#####PG
# d1516#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1520#####SET enable_nestloop TO off;
# d1542#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d156#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1568#####PG
# d159#####SET enable_nestloop TO off;
# d1591#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1606#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1608#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1611#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1612#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1624#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1627#####PG
# d1630#####PG
# d1653#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1682#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1683#####PG
# d1730#####SET enable_nestloop TO off;
# d1731#####SET enable_mergejoin TO off;
# d1737#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1746#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1758#####SET enable_mergejoin TO off;
# d1762#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1776#####PG
# d1778#####SET enable_nestloop TO off;
# d1800#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1839#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1849#####PG
# d185#####SET enable_mergejoin TO off;
# d1855#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d186#####PG
# d1876#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1880#####SET enable_nestloop TO off; SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1884#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1886#####PG
# d1897#####SET enable_nestloop TO off;
# d190#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1914#####PG
# d1937#####PG
# d1948#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1949#####SET enable_nestloop TO off;
# d196#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d1976#####PG
# d1984#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2010#####SET enable_nestloop TO off;
# d2024#####PG
# d2039#####SET enable_mergejoin TO off;
# d2086#####SET enable_nestloop TO off;
# d2095#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2099#####SET enable_nestloop TO off;
# d2116#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2152#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2153#####PG
# d2161#####PG
# d2165#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2181#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2198#####PG
# d2229#####SET enable_nestloop TO off;
# d2241#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2277#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2279#####PG
# d2283#####SET enable_nestloop TO off;
# d2285#####PG
# d2292#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2298#####SET enable_mergejoin TO off;
# d2310#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2323#####SET enable_mergejoin TO off;
# d233#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2359#####PG
# d2385#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2389#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d242#####PG
# d2427#####SET enable_nestloop TO off;
# d2430#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2451#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2458#####PG
# d2525#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2526#####PG
# d254#####PG
# d2541#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2565#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2580#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2593#####SET enable_mergejoin TO off;
# d2598#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2610#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2695#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d27#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2733#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2783#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d279#####PG
# d2791#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2793#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2821#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2836#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2889#####SET enable_mergejoin TO off;
# d2905#####SET enable_nestloop TO off;
# d2925#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2926#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2931#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2937#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2956#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2957#####PG
# d2961#####PG
# d2979#####PG
# d2981#####PG
# d2987#####PG
# d2988#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2990#####PG
# d2991#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d2994#####SET enable_mergejoin TO off;
# d3000#####PG
# d3002#####PG
# d3004#####SET enable_nestloop TO off;
# d3011#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3018#####PG
# d3030#####SET enable_mergejoin TO off;
# d3058#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3065#####PG
# d3066#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3076#####PG
# d3080#####PG
# d3097#####SET enable_nestloop TO off;
# d3152#####PG
# d3155#####SET enable_mergejoin TO off;
# d3156#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3169#####SET enable_nestloop TO off;
# d3191#####PG
# d3203#####SET enable_mergejoin TO off;
# d3204#####PG
# d3209#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d322#####PG
# d3234#####PG
# d3263#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3276#####PG
# d3317#####PG
# d3349#####SET enable_nestloop TO off;
# d3353#####PG
# d3362#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3364#####PG
# d339#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3423#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3425#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3444#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3456#####PG
# d3557#####PG
# d3581#####PG
# d3582#####PG
# d3603#####PG
# d3629#####PG
# d3641#####SET enable_mergejoin TO off;
# d3668#####PG
# d3682#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3697#####PG
# d3710#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3719#####SET enable_nestloop TO off;
# d3724#####SET enable_mergejoin TO off;
# d3725#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3736#####SET enable_nestloop TO off;
# d3738#####PG
# d376#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3780#####SET enable_nestloop TO off;
# d3802#####PG
# d3861#####PG
# d3877#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3884#####SET enable_nestloop TO off;
# d3893#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3897#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3909#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3920#####SET enable_nestloop TO off;
# d394#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3966#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d3970#####SET enable_nestloop TO off;
# d3971#####SET enable_nestloop TO off;
# d3976#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d4#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d410#####SET enable_mergejoin TO off;
# d419#####PG
# d420#####PG
# d449#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d450#####SET enable_nestloop TO off;
# d492#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d499#####SET enable_nestloop TO off;
# d543#####SET enable_nestloop TO off;
# d568#####SET enable_nestloop TO off;
# d599#####PG
# d608#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d610#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d612#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d619#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d627#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d629#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d637#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d638#####PG
# d644#####SET enable_mergejoin TO off;
# d71#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d770#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d783#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d830#####PG
# d848#####SET enable_nestloop TO off;
# d854#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d88#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d904#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d918#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d922#####SET enable_nestloop TO off;
# d936#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d940#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d941#####PG
# d946#####PG
# d955#####SET enable_mergejoin TO off;
# d971#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d975#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d977#####PG
# d984#####SET enable_mergejoin TO off; SET enable_indexscan TO off;
# d986#####SET enable_mergejoin TO off; SET enable_indexscan TO off;

# %%
import re

with open('/home/lgn/source/ai4db_baseline/baseline/Bao/backup4join_order/job-ext/test__bao__job_ext.txt')as f:
    log_text = f.read()

lines = log_text.strip().split('\n')

results = []

for line in lines:
    parts = line.split(',')
    plan_time = float(parts[-3].strip())
    if plan_time < 3000:
        results.append(plan_time)

print(len(results))
print(len(lines))
print(sum(results) / 1000.0)
print(sum(results) * len(lines) / len(results) / 1000.0)
# Out:
# 496
# 496
# 36.86462600000001
# 36.86462600000001
